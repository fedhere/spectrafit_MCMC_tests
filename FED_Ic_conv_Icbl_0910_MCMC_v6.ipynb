# %% [markdown]
# # CODE TO FIND VELOCITY BROADENING AND DOPPLER SHIFT IN Ic-BL BY FITTING THE MEAN Ic TEMPLATE TO THE Ic-BL SPECTRA

# %% [markdown]
# ## I am reproducing Yuqian's minimization, in python, while hers is in idl. I have her template, the mean Ic spectrum, and her spectrum for the Ic-BL PTF10qts. NOTE: i do not know what the variance is for the data, so my chi square is done without sigmas! (i.e. all sigma=1). this need to be fixed and may lead to very different minimization results of course. I am finding a different minimum. My minimization with powell, using scipy.optimize.minimize, takes <0.2 seconds per feature while Yuqian's seems to take a long long time: 95 second two minimize 2 line features...

# %%
import numpy as np
from scipy.io.idl import readsav
import pylab as pl
from scipy.ndimage import filters
from scipy.signal import  gaussian
from scipy.interpolate import interp1d
from scipy.optimize import minimize 
import time
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %% [markdown]
# #### function that fits the templates

# %%
def fittemplate(p,fmean_input,wlog_input,lx,ly,ly_err, plot=False, fig=None):
    #scale2=-p[3]*100
    scale1,v,sig,a=p[2]*100,-p[1]*1000,p[0]*10,p[3]
    w_lower=lx[0]+scale1
    w_upper=lx[-1]-scale1

    inds=(lx>w_lower) * (lx<w_upper)
    ly_new=ly[inds]
    ly_err_new=ly_err[inds]
    lx_new=lx[inds]

    doppler=1.0+v/299792.458
    b = gaussian(300, sig)
    thisy=filters.convolve1d(a*fmean_input, b/b.sum())  # first do Gaussian convolution
    f2 = interp1d(wlog_input*doppler, thisy,bounds_error=False, fill_value=0)(lx_new) 
    chisq=np.sum((ly_new-f2)**2/ly_err_new**2)/(len(ly_new)-len(p))
    
    if plot:
        if not fig:
            fig=figure(figsize=(15,15))
        fig.add_subplot(1,1,1)
        #pl.plot(wlog_input, fmean_input)
        pl.plot(x_flat,y_flat,'k',alpha=0.5)
        pl.plot(lx_new,ly_new,'k')
        pl.plot(lx_new,f2,'r',linewidth=3)
        pl.plot(wlog_input*doppler, fmean_input,'r',linewidth=2,alpha=0.5,label=r"scale1=%.2f $\AA$ v=%.2f km/s   $\sigma$=%.2f $\AA$   $\chi^2$=%.2f"%(scale1, -v,sig,chisq))
        pl.xlabel("wavelength (A)",fontsize=15)
        pl.ylabel("flux (normalized)",fontsize=15)
        pl.legend(fontsize=15)
    
    #print p,chisq
    return chisq

# %% [markdown]
# #### read in Icbl raw spectra with loadtxt.
# notice that the option  "unpack=True" inverts the columns and raws from the default, so that you do not have to transpose the output

# %%
dd=np.loadtxt("10qts_20100815_Lick_3-m_v1-z.flm", unpack=True) 
x,y=dd[0],dd[1] # wavelength, flux

# %% [markdown]
# #### x and y are wavelength and flux for the input data

# %% [markdown]
# #### read template which is saved in idl as a binary .sav file.
# the resulting structure has wavelenght in log space stored in wlog and flux stored in fmean

# %%
s=readsav('meanspecIc_1specperSN_0.sav') # read in Ic template

# %%
pl.plot(s.wlog,s.fmean)
pl.xlabel("wavelength (A)")
pl.ylabel("flux (normalized)")
pl.title ("template spectrum (Ic-mean)")

# %% [markdown]
# #### only the wavelenth range 4400 - 9000 is relevant. notice 9000, at least for this particular spectrum, rather than 10000 is my upper limit

# %%
wlog_input=s.wlog[where((s.wlog > 4400) & (s.wlog < 9000))]
fmean_input=s.fmean[where((s.wlog > 4400) & (s.wlog < 9000))]

pl.plot(s.wlog, s.fmean,alpha=0.5) 
pl.xlim(2000, 10000)
pl.xlabel("wavelength (A)")
pl.ylabel("flux (normalized)")
pl.title ("template spectrum (Ic-mean)")
pl.figure(1)
pl.plot(wlog_input, fmean_input,'b',linewidth=3) # plot Ic template - the shift & convolution part
pl.xlim(2000, 10000)
# Out:
# (2000, 10000)

# %% [markdown]
# #### read the flattened SN spectrum in, which is saved in idl as a binary .sav file.
# the resulting structure hosts wavelength in wavelog_input and flux in flatflux_input.
# let's save them into more conveniently names variables x_flat and y_flat

# %%
s2=readsav('10qts_20100815_Lick_3-m_v1-z.flm-flat.sav') # read in Icbl flattened spectra
x_flat=s2.wavelog_input[0:1024]
y_flat=s2.flatflux_input
y_flat_err=s2.flatflux_err_input
size(x_flat),size(y_flat),size(y_flat_err), size(y_flat-y_flat_err)
# Out:
# (1024, 1024, 1024, 1024)

# %% [markdown]
# #### plot the SN spectrum (x,y) and the flattened SN spectrum x_flat,y_flat

# %%
pl.figure(figsize=(15,15))
pl.title("PTF 10qts 20100815",fontsize=15)
pl.plot(x,y,'b',label="original spectrum") # plot Icbl raw spectra
pl.xlim(2000, 10000)
pl.plot(x_flat,y_flat,'r',label="flat spectrum") # plot Icbl flattened spectra
pl.xlim(2000, 10000)
#pl.plot(x_flat,y_flat_err,'g',label="errors of flat spectrum") # plot errors of Icbl flattened spectra
#pl.xlim(2000, 10000)
pl.fill_between(x_flat,y_flat-y_flat_err,y_flat+y_flat_err, color='r', alpha=0.2) # plot errors of Icbl flattened spectra
pl.xlabel("wavelength (A)",fontsize=15)
pl.ylabel("flux (normalized)",fontsize=15)
pl.legend()

# %% [markdown]
# ### NOTE: the wavelength range you suggested is 4400-5100 A and 5200-6300 A for Fe and Si respectively.
# however i think 4400 includes too much of the peak blueward of the Fe triplet (at least for this SN), which we know hosts a spectral feature present in Ic but in absent in Ic-BL. I think 4500-5100 is a better range fot the Fe triplet feature in the template

# %%
pl.figure(figsize=(15,15))
pl.title("PTF 10qts 20100815")
pl.plot(x_flat,y_flat,'k',alpha=0.5) # plot Icbl flattened spectra
Fe_lower=4400 
Fe_upper=5200
Si_lower=5100
Si_upper=6400
Fex=x_flat[np.where((x_flat>Fe_lower) & (x_flat<Fe_upper))]
Fey=y_flat[np.where((x_flat>Fe_lower) & (x_flat<Fe_upper))]
Fey_err=y_flat_err[np.where((x_flat>Fe_lower) & (x_flat<Fe_upper))]
Six=x_flat[np.where((x_flat>Si_lower) & (x_flat<Si_upper))]
Siy=y_flat[np.where((x_flat>Si_lower) & (x_flat<Si_upper))]
Siy_err=y_flat_err[np.where((x_flat>Si_lower) & (x_flat<Si_upper))]
pl.plot(Fex,Fey,'k',linewidth=2)
pl.plot(Six,Siy,'k',linewidth=2)
pl.text(mean(Fex),0.2,"Fe",ha='center',fontsize=30)
pl.text(mean(Six),0.2,"Si",ha='center',fontsize=30)
pl.xlim(2000, 10000)
pl.xlabel("wavelength")
pl.ylabel("flux (normalized)")

# %% [markdown]
# #### initialization of the minimization: the initial guess as Yuqian said is 8000 km/s and 20 A. However these numbers are 2.5 order of magnitudes apart. Most minimization routines work best if the parameters are in the same order of magnitude, at least, so i use units for the parameters to be passed to my fit function, and i scale the velocity parameters by 10^3 and the width by 10 inside the function.

# %%
p0=np.array([2,8,1,1])
fig=figure(figsize=(5,5))
fittemplate(p0,fmean_input,wlog_input,Fex,Fey,Fey_err,plot=True,fig=fig)
# Out:
# 5.2732249292834048

# %%
t1 = time.time()
resFe=minimize(fittemplate, p0, args=(fmean_input,wlog_input,Fex,Fey, Fey_err), method='Powell')
t2 = time.time()
print 'minimization took {} seconds'.format(t2 - t1)
print "Fe minimization with initial guess: sigma=",p0[0]*10,"A, v=", p0[1]*1000,"km/s", p0[2]*100, "A"#, p0[3]*100, "A"
print " sigma:",resFe['x'][0]*10,"A, v=", resFe['x'][1]*1000,"km/s", resFe['x'][2]*100, 'A'#, resFe['x'][3]*100, 'A'
# Out:
# minimization took 0.236934900284 seconds
# Fe minimization with initial guess: sigma= 20 A, v= 8000 km/s 100 A
#  sigma: 11.7583184841 A, v= 10670.4830424 km/s 180.156013118 A

# %% [markdown]
# ### NOTE: you suggest to use a different initial guess for Fe and Si. I do not think this is a good idea.
#     If you had any sort of a priori knowledge it would be the fact that the velocity should be similar for both lines. So you should either the same starting point for both lines, or the result of the fit to one line to initiate the other. Below i do all of the above things, and I find the same minimization in all cases!!

# %% [markdown]
# #### Yuqian initialization parameters for Si

# %%
p0=np.array([2,3,1,1])
fig=figure(figsize=(5,5))
fittemplate(p0,fmean_input,wlog_input,Six,Siy,Siy_err,plot=True,fig=fig)
t1 = time.time()
resSi=minimize(fittemplate, p0, args=(fmean_input,wlog_input,Six,Siy,Siy_err), method='Powell')
t2 = time.time()
print 'minimization took {} seconds'.format(t2 - t1)
print "Si minimization with initial guess: sigma=",p0[0]*10,"A, v=", p0[1]*1000,"km/s", p0[2]*100, "A"#, p0[3]*100, "A"
print " sigma:",resSi['x'][0]*10,"A, v=", resSi['x'][1]*1000,"km/s", resSi['x'][2]*100,"A"#, resSi['x'][3]*100,"A"
# Out:
# minimization took 0.181924104691 seconds
# Si minimization with initial guess: sigma= 20 A, v= 3000 km/s 100 A
#  sigma: 42.6566020947 A, v= 4609.36315333 km/s 128.507314257 A

# %% [markdown]
# #### Fe best fit for  initialization parameters for Si

# %%
p0=resFe['x']
fig=figure(figsize=(5,5))
fittemplate(p0,fmean_input,wlog_input,Six,Siy,Siy_err,plot=True,fig=fig)
t1 = time.time()
resSi=minimize(fittemplate, p0, args=(fmean_input,wlog_input,Six,Siy,Siy_err), method='Powell')
t2 = time.time()
print 'minimization took {} seconds'.format(t2 - t1)
print "Si minimization with initial guess: sigma=",p0[0]*10,"A, v=", p0[1]*1000,"km/s", p0[2]*100, "A"#, p0[3]*100, "A"
print " sigma:",resSi['x'][0]*10,"A, v=", resSi['x'][1]*1000,"km/s",resSi['x'][2]*100,"A"#,resSi['x'][3]*100,"A"
# Out:
# minimization took 0.177938938141 seconds
# Si minimization with initial guess: sigma= 10.8739345163 A, v= 10460.3456934 km/s 186.522764412 A
#  sigma: 48.1582266707 A, v= 5273.54841902 km/s 128.507552792 A

# %% [markdown]
# #### Same parameters for Si as for Fe

# %%
p0=np.array([2,8,1,1])
fig=figure(figsize=(5,5))
fittemplate(p0,fmean_input,wlog_input,Six,Siy,Siy_err,plot=True,fig=fig)
t1 = time.time()
resSi=minimize(fittemplate, p0, args=(fmean_input,wlog_input,Six,Siy, Siy_err), method='Powell')
t2 = time.time()
print 'minimization took {} seconds'.format(t2 - t1)
print "Si minimization with initial guess: sigma=",p0[0]*10,"A, v=", p0[1]*1000,"km/s", p0[2]*100, "A"#, p0[3]*100, "A"
print " sigma:",resSi['x'][0]*10,"A, v=", resSi['x'][1]*1000,"km/s",resSi['x'][2]*100, "A"#,resSi['x'][3]*100, "A"
# Out:
# minimization took 0.307118177414 seconds
# Si minimization with initial guess: sigma= 20 A, v= 8000 km/s 100 A
#  sigma: 45.5485249005 A, v= 4762.71824209 km/s 119.310437499 A

# %% [markdown]
# #### Si best fit for  initialization parameters for Fe

# %%
p0=resSi['x']
fig=figure(figsize=(5,5))
fittemplate(p0,fmean_input,wlog_input,Fex,Fey,Fey_err,plot=True,fig=fig)
t1 = time.time()
resFe=minimize(fittemplate, p0, args=(fmean_input,wlog_input,Fex,Fey, Fey_err), method='Powell')
t2 = time.time()
print 'minimization took {} seconds'.format(t2 - t1)
print "Fe minimization with initial guess: sigma=",p0[0]*10,"A, v=", p0[1]*1000,"km/s",p0[2]*100,"A"#,p0[3]*100,"A"
print " sigma:",resFe['x'][0]*10,"A, v=", resFe['x'][1]*1000,"km/s", "scale: ", resFe['x'][2]*100#, "A", resFe['x'][3]*100, "A"
# Out:
# minimization took 0.369439840317 seconds
# Fe minimization with initial guess: sigma= 45.5485249005 A, v= 4762.71824209 km/s 119.310437499 A
#  sigma: 10.8739345163 A, v= 10460.3456934 km/s scale:  186.522764412

# %%
fittemplate(resFe['x'],fmean_input,wlog_input,Fex,Fey,Fey_err,plot=True)
fittemplate(resSi['x'],fmean_input,wlog_input,Six,Siy,Siy_err,plot=True)
# Out:
# 1.1988779315511688

# %% [markdown]
# ## YUQIAN gets a different minimization result!
# v = 8430 km/s  sigma = 174 angstrom
# without error bars this fit has a higher chisq than my minima

# %%
fig=figure(figsize=(5,5))
fittemplate([1.74,8.430,1,1],fmean_input,wlog_input,Fex,Fey,Fey_err,plot=True,fig=fig)
fig=figure(figsize=(5,5))
fittemplate([1.09,4.919,1,1],fmean_input,wlog_input,Six,Siy,Siy_err,plot=True,fig=fig)
# Out:
# 3.7460699642405793

# %% [markdown]
# ## MCMC to get the errors

# %% [markdown]
# #### likelihood definitions

# %%
def logprior (p):
    s=p[0]
    v=p[1]
    scale1=p[2]
    #scale2=p[3]
    
    if v>0 and s>0 and v>0.5 and scale1>0 and scale1<2 and p[3]>0: # and scale2>0 and scale1<3 and scale2<3: 
        return 0.0
    return -np.inf

def logl(p,x,y,s,fmean_input,wlog_input):
    return  -np.log(s)-0.5*(fittemplate(p,fmean_input,wlog_input,x,y,s))
    
def logp(p,x,y,s,fmean_input,wlog_input):
    lgl= logl(p,x,y,s,fmean_input,wlog_input)
    #print lgl
    return np.sum(logprior(p)+lgl)

# %%
import triangle 
import emcee

Fes=Fey_err #np.ones(len(Fex))/np.sqrt(len(Fex))
Sis=Siy_err #np.ones(len(Six))/np.sqrt(len(Six))
##ndim, nwalkers = 2, 32
fig1=pl.figure(10)
fig2=pl.figure(11)
ndim, nwalkers = 4, 6*2

# %% [markdown]
# #### Fe MCMC

# %%
best_pos=[]
#p00=np.array([2,8,1])
#p0 = [p00 + 1e-6*np.random.randn(ndim) for i in range(nwalkers)]
p0 = [resFe["x"] + 1e-6*np.random.randn(ndim) for i in range(nwalkers)]
samplerFe = emcee.EnsembleSampler(nwalkers, ndim, logp, 
                                        args=(Fex,Fey,Fes,fmean_input,wlog_input))
pos, prob, state = samplerFe.run_mcmc(p0, 30)
best_pos.append(samplerFe.flatchain[samplerFe.flatlnprobability.argmax()])
pos = emcee.utils.sample_ball(best_pos[-1], best_pos[-1]/100., size=nwalkers)
samplerFe.reset()
pos, prob, state = samplerFe.run_mcmc(pos, 1000)
best_pos.append(samplerFe.flatchain[samplerFe.flatlnprobability.argmax()])

fig1 = triangle.corner(samplerFe.flatchain, 
                           truths=best_pos[-1], figure=fig1,labels=["r$\sigma$", "$v$", "$scale1$", "norm"])

# %%
print("Mean acceptance fraction: {0:.3f}"
                .format(np.mean(samplerFe.acceptance_fraction)))
print best_pos[-1]
for i in range(ndim):
    pl.figure(figsize=(15,2))
    pl.plot(range(1000),samplerFe.chain[:,:,i].T)
    pl.xlabel("steps")

samples = samplerFe.chain[:, 50:, :].reshape((-1, ndim))
#samples[:, 2] = np.exp(samples[:, 2])
sigma_mcmc, v_mcmc, scale_mcmc, a_mcmc = map(lambda v: (v[1], v[2]-v[1], v[1]-v[0]),
                             zip(*np.percentile(samples, [16, 50, 84],
                                             axis=0)))
print sigma_mcmc, v_mcmc, scale_mcmc, a_mcmc
fig1 = triangle.corner(samplerFe.flatchain, 
                           truths=[sigma_mcmc[0], v_mcmc[0], scale_mcmc[0], a_mcmc[0]], figure=fig1,labels=[r"$\sigma$", "$v$", "$scale1$", "norm"])

fittemplate([sigma_mcmc[0], v_mcmc[0], scale_mcmc[0], a_mcmc[0]],fmean_input,wlog_input,Fex,Fey,Fes,plot=True)
# Out:
# Mean acceptance fraction: 0.522
# [ 4.55485102  4.76271738  1.19310308  1.31261623]
# (1.1746220836165064, 0.069910244099676833, 0.063570502450404298)
#  (10.661147643989944, 0.2301162719190657, 0.23150961181927698) (1.8279280748239843, 0.059500348499008648, 0.027730426047719137) (1.5568982546072581, 0.077756099425748904, 0.072142409909240479)
# 1.2391591306592598

# %% [markdown]
# #### Si MCMC

# %%
best_pos=[]
p0 = [resSi["x"] + 1e-6*np.random.randn(ndim) for i in range(nwalkers)]
samplerSi = emcee.EnsembleSampler(nwalkers, ndim, logp, 
                                        args=(Six,Siy,Sis,fmean_input,wlog_input))
pos, prob, state = samplerSi.run_mcmc(p0, 30)
best_pos.append(samplerSi.flatchain[samplerSi.flatlnprobability.argmax()])
pos = emcee.utils.sample_ball(best_pos[-1], best_pos[-1]/100., size=nwalkers)
samplerSi.reset()
pos, prob, state = samplerSi.run_mcmc(p0, 1000)
best_pos.append(samplerSi.flatchain[samplerSi.flatlnprobability.argmax()])
#tmpb= samplerSi.flatchain.T[0][np.where((samplerSi.flatchain.T[0]<best_pos[-1][0]*10)&(samplerSi.flatchain.T[1]<best_pos[-1][1]*10))]
#tmpv= samplerSi.flatchain.T[1][np.where((samplerSi.flatchain.T[0]<best_pos[-1][0]*10)&(samplerSi.flatchain.T[1]<best_pos[-1][1]*10))]

#fig2 = triangle.corner(np.array([tmpb,tmpv]).T, 
fig2 = triangle.corner(samplerSi.flatchain, 
                       truths=best_pos[-1], figure=fig2,labels=["r$\sigma$", "$v$", "$scale$", "norm"])
print best_pos[-1]
for i in range(ndim):
    pl.figure(figsize=(15,2))
    pl.plot(range(1000),samplerSi.chain[:,:,i].T)
    #pl.ylim(np.median(samplerSi.chain[:,:,i].T[100])-10,np.median(samplerSi.chain[:,:,i].T[100])+10)
    pl.xlabel("steps")

fittemplate(best_pos[-1],fmean_input,wlog_input,Six,Siy,Sis,plot=True)
# Out:
# [ 4.55485345  4.76271857  1.19310363  1.31261554]
# 1.1988781645097806

# %%
print("Mean acceptance fraction: {0:.3f}"
                      .format(np.mean(samplerSi.acceptance_fraction)))
        
samples = samplerSi.chain[:, 250:, :].reshape((-1, ndim))
#samples[:, 2] = np.exp(samples[:, 2])
sigma_mcmc, v_mcmc, scale_mcmc, a_mcmc = map(lambda v: (v[1], v[2]-v[1], v[1]-v[0]),
                             zip(*np.percentile(samples, [16, 50, 84],
                                             axis=0)))
print sigma_mcmc, v_mcmc, scale_mcmc, a_mcmc
fig1 = triangle.corner(samplerSi.flatchain, 
                           truths=[sigma_mcmc[0], v_mcmc[0], scale_mcmc[0], a_mcmc[0]], figure=fig1,labels=[r"$\sigma$", "$v$", "$scale1$", "norm"])


fittemplate([sigma_mcmc[0], v_mcmc[0], scale_mcmc[0], a_mcmc[0]],fmean_input,wlog_input,Six,Siy,Sis,plot=True)
# Out:
# Mean acceptance fraction: 0.483
# (4.6290612391663508, 0.51310319822992234, 0.55385729476256618) (4.862745905107122, 1.3408141652013903, 0.92860714297474889) (1.2751224647698531, 0.06989086864060079, 0.31171742399031843) (1.3448590291609257, 0.47026652571731775, 0.39704534358848464)
# 1.2034618762112403
